# %%
import os
import pandas as pd
import csv

# %%
DIRETORIO_ATUAL = os.getcwd() 

FICHEIRO_ENTRADA = os.path.join(DIRETORIO_ATUAL, "dataset_emocoes_raw.csv")

# %%
df = pd.read_csv(FICHEIRO_ENTRADA)

print(pd.Series.value_counts(df['Contexto_Label']))
# Out:
# Contexto_Label
# Jogar        520252
# Trabalhar    260300
# Lazer         51972
# Ler           38082
# Name: count, dtype: int64
